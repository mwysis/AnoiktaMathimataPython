# %%
# pip install --user folium
import folium
# from IPython.display import IFrame

# %%
# map = folium.Map(location=[38.2466, 21.7346], zoom_start=12)
# dir(folium.Map)
# map.get_bounds()
# map.save('patras.html')
# IFrame('patras.html', width=700, height=700)

# %%
map1 = folium.Map(location=[39.0742, 21.8243], zoom_start=6)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map1 = folium.Map(location=[39.0742, 21.8243], tiles='Mapbox Control Room', zoom_start=6)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map2 = folium.Map(location=[38.2466, 21.7346], tiles='Stamen Toner', zoom_start=16) 
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map3 = folium.Map(location=[38.263716, 21.745575], tiles='Stamen Toner', zoom_start=16)
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map_4 = folium.Map(location=[38.263716, 21.745575], tiles='Stamen Toner', zoom_start=16)
map_4.simple_marker(location=[38.266985, 21.744535], popup='Physique Gym')
map_4.circle_marker(location=[38.263716, 21.745575], radius=500,
                    popup='Agyia', line_color='#3186cc',
                    fill_color='#3186cc')
map_4
# Out:
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
#   from ipykernel import kernelapp as app
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: circle_marker is deprecated. Use add_children(CircleMarker) instead
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
from folium.plugins import MarkerCluster
map_5 = folium.Map(location=[38.263716, 21.745575], zoom_start=15.)
locations = [[38.266985, 21.744535]]
popups = ['Physique Gym'.format(loc) for loc in locations]
map_5.add_children(MarkerCluster(locations=locations, popups=popups))
map_5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map = folium.Map(location=[36.107000, -112.113005], tiles='Stamen Terrain', zoom_start=14)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map = folium.Map(location=[41.142110, 24.891039], tiles='Stamen Toner', zoom_start=17)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
coordinates = [
     [  42.3581    ,  -71.0636    ],
     [  42.82995815,  -74.78991444],
     [  43.17929819,  -78.56603306],
     [  43.40320216,  -82.37774519],
     [  43.49975489,  -86.20965845],
     [  43.46811941,  -90.04569087],
     [  43.30857071,  -93.86961818],
     [  43.02248456,  -97.66563267],
     [  42.61228259, -101.41886832],
     [  42.08133868, -105.11585198],
     [  41.4338549 , -108.74485069],
     [  40.67471747, -112.29609954],
     [  39.8093434 , -115.76190821],
     [  38.84352776, -119.13665678],
     [  37.7833    , -122.4167    ]]
m = folium.Map(location=[41.9, -97.3], zoom_start=4)
# my_PolyLine=folium.PolyLine(locations=coordinates,weight=5)
# m.add_children(my_PolyLine)
m.line(coordinates, line_color='#FF0000', line_weight=5)
m
# Out:
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:20: FutureWarning: line is deprecated. Use add_children(PolyLine) instead
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
coordinates = [
     [  38.250540, 21.742443  ],
     [  37.930615, 22.934459  ],
     [  39.367705, 22.939952  ],
     [  39.637634, 22.430926],
     [  40.656515, 22.965580],
     [  41.135579, 24.882426],
     [  40.849656, 25.871653],
     [  39.128460, 26.541132],
     [  37.767214, 26.966184],
     [  36.419761, 28.208991],
     [  35.347474, 25.123494],
     [  37.062144, 22.099869],
     [  39.639178, 19.909437],
     [  39.671783, 20.854334],
     [  38.906528, 22.436365    ],
     [  38.250540, 21.742443  ]]
m = folium.Map(location=[38.0, 23.7], zoom_start=7)
m.line(coordinates, line_color='#FF0000', line_weight=5)
m
# Out:
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:19: FutureWarning: line is deprecated. Use add_children(PolyLine) instead
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
coordinates1 = [
     [  38.250540, 21.742443  ],
     [  37.930615, 22.934459  ]]
coordinates2 = [
     [  38.250540, 21.742443  ],
     [  39.367705, 22.939952  ]]
coordinates3 = [
     [  38.250540, 21.742443  ],
     [  39.637634, 22.430926]]
coordinates4 = [
     [  38.250540, 21.742443  ],
     [  40.656515, 22.965580],
     [  41.135579, 24.882426]]
coordinates5 = [
     [  41.135579, 24.882426],
     [  40.849656, 25.871653],
     [  39.128460, 26.541132],
     [  37.767214, 26.966184]]
coordinates6 = [
     [  37.930615, 22.934459  ],
     [  36.419761, 28.208991],
     [  35.347474, 25.123494]]
coordinates7 = [
     [  39.367705, 22.939952  ],
     [  37.062144, 22.099869]]
coordinates8 = [
     [  39.128460, 26.541132],
     [  39.639178, 19.909437],
     [  39.671783, 20.854334]]
coordinates9 = [
     [  36.419761, 28.208991],
     [  38.906528, 22.436365    ],
     [  38.250540, 21.742443  ],
     [  36.419761, 28.208991]]
coordinates10 = [
     [  37.071065, 22.095789],
     [  35.346028, 25.115169]]
coordinates11 = [
     [  40.658755, 22.932533],
     [  39.605644, 19.914772]]
coordinates12 = [
     [  41.139099, 24.889752],
     [  37.761791, 26.967582]]
m = folium.Map(location=[38.0, 23.7], tiles='Mapbox Control Room', zoom_start=7)
m.line(coordinates1, line_color='#FF0000', line_weight=5)
m.line(coordinates2, line_color='#FF0000', line_weight=5)
m.line(coordinates3, line_color='#FF0000', line_weight=5)
m.line(coordinates4, line_color='#FF0000', line_weight=5)
m.line(coordinates5, line_color='#FF0000', line_weight=5)
m.line(coordinates6, line_color='#FF0000', line_weight=5)
m.line(coordinates7, line_color='#FF0000', line_weight=5)
m.line(coordinates8, line_color='#FF0000', line_weight=5)
m.line(coordinates9, line_color='#FF0000', line_weight=5)
m.line(coordinates10, line_color='#FF0000', line_weight=5)
m.line(coordinates11, line_color='#FF0000', line_weight=5)
m.line(coordinates12, line_color='#FF0000', line_weight=5)
m
# Out:
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:45: FutureWarning: line is deprecated. Use add_children(PolyLine) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:46: FutureWarning: line is deprecated. Use add_children(PolyLine) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:47: FutureWarning: line is deprecated. Use add_children(PolyLine) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:48: FutureWarning: line is deprecated. Use add_children(PolyLine) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:49: FutureWarning: line is deprecated. Use add_children(PolyLine) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:50: FutureWarning: line is deprecated. Use add_children(PolyLine) instead
# ...

# %%
ice_map = folium.Map(location=[-59.1759, -11.6016],
                   tiles='Mapbox Bright', zoom_start=2)

folium.GeoJson(open('folium-master/examples/antarctic_ice_edge.json'),
               name='geojson'
              ).add_to(ice_map)

folium.TopoJson(open('folium-master/examples/antarctic_ice_shelf_topo.json'),
                'objects.antarctic_ice_shelf',
                name='topojson',
               ).add_to(ice_map)

folium.LayerControl().add_to(ice_map)
ice_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
coordinates = [
     [  41.131639, 24.888128  ],    #Xanthi
     [  40.640599, 22.942937  ],    #Thessaloniki
     [  37.985285, 23.727181  ],    #Athens
    
     [  29.765634, -95.364247],
    
     [  37.985285, 23.727181  ],    #Athens
    
     [  39.291063, -76.614651],
    
    [  29.765634, -95.364247],
     
    [  37.985285, 23.727181  ],    #Athens
    
     [  41.131639, 24.888128],
    
     [  43.769773, 11.257446],
    
     [  48.857256, 2.352705],
    
     [  41.131639, 24.888128],
    
     [  33.683838, -117.790734],
    
#      [  40.640599, 22.942937],
    
    [  41.131639, 24.888128],
    
     [  38.248065, 21.735134]   #Patras
    ]
m = folium.Map(location=[38.0, 23.7], tiles='Mapbox Control Room', zoom_start=3)
m.line(coordinates, line_color='#FF0000', line_weight=5)
m.simple_marker(location=[41.131639, 24.888128], popup='Xanthi')
m.simple_marker(location=[40.640599, 22.942937], popup='Thessaloniki')
m.simple_marker(location=[37.985285, 23.727181], popup='Athens')
m.simple_marker(location=[29.765634, -95.364247], popup='Houston')
m.simple_marker(location=[39.291063, -76.614651], popup='Baltimore')
m.simple_marker(location=[43.769773, 11.257446], popup='Firenze')
m.simple_marker(location=[48.857256, 2.352705], popup='Paris')
m.simple_marker(location=[33.683838, -117.790734], popup='Los Angeles')
m.simple_marker(location=[38.248065, 21.735134], popup='Patras')
m
# Out:
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:33: FutureWarning: line is deprecated. Use add_children(PolyLine) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:34: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:35: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:36: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:37: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
# /Users/mosesboudourides/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:38: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
# ...
